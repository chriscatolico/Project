# %%
import requests
import json
import pprint
import pandas as pd
from config import api_key
from citipy import citipy
import random
import numpy as np

# %%
maxlatitude, minlatitude = 49.3457868, 24.7433195 
maxlongitude, minlongitude = -66.9513812, -124.7844079

# %%
cities = []
coordinates = []
i=0

while len(cities)<5:
    lat, long = (random.uniform(minlatitude,maxlatitude),random.uniform(minlongitude,maxlongitude))
    if citipy.nearest_city(lat, long).country_code == 'us':
        cities.append(citipy.nearest_city(lat, long))
        coordinates.append((lat,long))
        print(cities[i].city_name + " "+ cities[i].country_code)
        i+=1
# Out:
# huron us
# meridian us
# dickinson us
# altamont us
# hondo us

# %%
url = 'https://api.yelp.com/v3/businesses/search'
key = api_key

headers = {'Authorization': f'Bearer {key}'
          }

# %%
params = []

for lat, long in coordinates:
    params.append({"key": "hotdogs", #hotdogs is yelp's category keyword for fastfood
              'latitude': 37.8085393,
              'longitude': -122.4196538,
              'radius': '20000',
              'limit': 50,
              'sort_by': 'distance',
              'price':'1,2'
             })

# %%
responses = []

responses.append(requests.get('https://api.yelp.com/v3/businesses/search', headers=headers, params = params[0]).json())

# %%
pprint.pprint(responses)
# Out:
# [{'businesses': [{'alias': 'cioppinos-san-francisco',
#                   'categories': [{'alias': 'italian', 'title': 'Italian'},
#                                  {'alias': 'seafood', 'title': 'Seafood'},
#                                  {'alias': 'bars', 'title': 'Bars'}],
#                   'coordinates': {'latitude': 37.8079387690789,
#                                   'longitude': -122.41927103988},
#                   'display_phone': '(415) 775-9311',
#                   'distance': 74.76449753029485,
#                   'id': '6h7YCp2KLfbu3tbRmNSb-g',
#                   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ODH70cD6EqVIif8bO4OYkw/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '400 Jefferson St',
#                                'address2': '',
#                                'address3': '',
#                                'city': 'San Francisco',
#                                'country': 'US',
#                                'display_address': ['400 Jefferson St',
#                                                    'San Francisco, CA 94109'],
#                                'state': 'CA',
#                                'zip_code': '94109'},
#                   'name': "Cioppino's",
#                   'phone': '+14157759311',
#                   'price': '$$',
#                   'rating': 3.5,
#                   'review_count': 1495,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/cioppinos-san-francisco?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'},
#                  {'alias': 'flying-ninja-sushi-san-francisco',
#                   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#                                  {'alias': 'sushi', 'title': 'Sushi Bars'}],
#                   'coordinates': {'latitude': 37.8075812443507,
#                                   'longitude': -122.419800814433},
#                   'display_phone': '(415) 292-6255',
#                   'distance': 107.31086657032908,
#                   'id': 'SaBTJzdovl39OGUxnbvvmw',
#                   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/NQ9m_9t65YJVp_1FD-o0ig/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '461 Jefferson St',
#                                'address2': '',
#                                'address3': '',
#                                'city': 'San Francisco',
#                                'country': 'US',
#                                'display_address': ['461 Jefferson St',
#                                                    'San Francisco, CA 94109'],
#                                'state': 'CA',
#                                'zip_code': '94109'},
#                   'name': 'Flying Ninja Sushi',
#                   'phone': '+14152926255',
#                   'price': '$$',
#                   'rating': 3.5,
#                   'review_count': 187,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/flying-ninja-sushi-san-francisco?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'},
#                  {'alias': 'blue-mermaid-restaurant-san-francisco-3',
#                   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#                                  {'alias': 'cocktailbars',
#                                   'title': 'Cocktail Bars'}],
#                   'coordinates': {'latitude': 37.8076036,
#                                   'longitude': -122.4200222},
#                   'display_phone': '(415) 771-2222',
#                   'distance': 108.96246335515379,
#                   'id': 'YQjAeNqo9V8Xw_ECSj7eHQ',
#                   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/b2KMM3p1tihN4wYNfjSvYQ/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '495 Jefferson St',
#                                'address2': '',
#                                'address3': '',
#                                'city': 'San Francisco',
#                                'country': 'US',
#                                'display_address': ['495 Jefferson St',
#                                                    'San Francisco, CA 94109'],
#                                'state': 'CA',
#                                'zip_code': '94109'},
#                   'name': 'Blue Mermaid Restaurant',
#                   'phone': '+14157712222',
#                   'price': '$$',
#                   'rating': 3.5,
#                   'review_count': 743,
#                   'transactions': ['delivery', 'pickup'],
#                   'url': 'https://www.yelp.com/biz/blue-mermaid-restaurant-san-francisco-3?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'},
#                  {'alias': 'the-crepe-cafe-san-francisco-2',
#                   'categories': [{'alias': 'french', 'title': 'French'},
#                                  {'alias': 'creperies', 'title': 'Creperies'}],
#                   'coordinates': {'latitude': 37.8077276323999,
#                                   'longitude': -122.41876962564},
#                   'display_phone': '(415) 346-3219',
#                   'distance': 119.07646813779606,
#                   'id': '81t6N_ZF3kxcU6sSPLhAEQ',
#                   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tImDJFYNLTTXEFCmWKWKGg/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '333 Jefferson St',
#                                'address2': 'Ste 5A',
#                                'address3': '',
#                                'city': 'San Francisco',
#                                'country': 'US',
#                                'display_address': ['333 Jefferson St',
#                                                    'Ste 5A',
#                                                    'San Francisco, CA 94133'],
#                                'state': 'CA',
#                                'zip_code': '94133'},
#                   'name': 'The Crepe Cafe',
#                   'phone': '+14153463219',
#                   'price': '$$',
#                   'rating': 4.0,
#                   'review_count': 82,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/the-crepe-cafe-san-francisco-2?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'},
#                  {'alias': 'in-n-out-burger-san-francisco',
#                   'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#                                  {'alias': 'burgers', 'title': 'Burgers'}],
#                   'coordinates': {'latitude': 37.80775,
#                                   'longitude': -122.41853},
#                   'display_phone': '(800) 786-1000',
#                   'distance': 132.0984124101008,
#                   'id': '_RysiB_bqTgCBmG8W96H4A',
#                   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tJVUUu5pauW2JwhaxpPl9g/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '333 Jefferson St',
#                                'address2': '',
#                                'address3': '',
#                                'city': 'San Francisco',
#                                'country': 'US',
#                                'display_address': ['333 Jefferson St',
#                                                    'San Francisco, CA 94133'],
#                                'state': 'CA',
#                                'zip_code': '94133'},
#                   'name': 'In-N-Out Burger',
#                   'phone': '+18007861000',
#                   'price': '$',
#                   'rating': 4.0,
#                   'review_count': 1740,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/in-n-out-burger-san-francisco?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'},
#                  {'alias': 'ben-and-jerrys-san-francisco-9',
#                   'categories': [{'alias': 'icecream',
#                                   'title': 'Ice Cream & Frozen Yogurt'}],
#                   'coordinates': {'latitude': 37.8075229,
#                                   'longitude': -122.4200887},
#                   'display_phone': '(415) 567-5873',
#                   'distance': 136.44020621375256,
#                   'id': '6ZtboMEvQg1DkPtlJG0GtA',
#                   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tdqzRBqFV8sq-V8xiVNjNg/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '475 Jefferson St',
#                                'address2': None,
#                                'address3': '',
#                                'city': 'San Francisco',
#                                'country': 'US',
#                                'display_address': ['475 Jefferson St',
#                                                    'San Francisco, CA 94109'],
#                                'state': 'CA',
#                                'zip_code': '94109'},
#                   'name': "Ben & Jerry's",
#                   'phone': '+14155675873',
#                   'price': '$$',
#                   'rating': 3.5,
#                   'review_count': 52,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/ben-and-jerrys-san-francisco-9?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'},
#                  {'alias': 'chilis-espanola-3',
#                   'categories': [{'alias': 'bars', 'title': 'Bars'},
#                                  {'alias': 'tex-mex', 'title': 'Tex-Mex'},
#                                  {'alias': 'tradamerican',
#                                   'title': 'American (Traditional)'}],
#                   'coordinates': {'latitude': 36.012799,
#                                   'longitude': -106.065234},
#                   'display_phone': '(505) 753-6667',
#                   'distance': 138.605889531095,
#                   'id': 'pD8PeyErCKE3Bw2kbkr1rw',
#                   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lAEKSP-cPAlIC0Xrig27Iw/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '415 Lowder Milk Rd',
#                                'address2': '',
#                                'address3': '',
#                                'city': 'Espanola',
#                                'country': 'US',
#                                'display_address': ['415 Lowder Milk Rd',
#                                                    'Espanola, NM 87532'],
#                                'state': 'NM',
#                                'zip_code': '87532'},
#                   'name': "Chili's",
#                   'phone': '+15057536667',
#                   'price': '$$',
#                   'rating': 2.5,
#                   'review_count': 23,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/chilis-espanola-3?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'},
#                  {'alias': 'pompeis-grotto-san-francisco',
#                   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#                                  {'alias': 'italian', 'title': 'Italian'}],
#                   'coordinates': {'latitude': 37.8080446,
#                                   'longitude': -122.4181205},
#                   'display_phone': '(415) 776-9265',
#                   'distance': 142.80128873350037,
#                   'id': 'xpFbTEEa-I1UHJxKgKNH8w',
#                   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/s8qUzWl2F7U0WZDVUdDe_Q/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '340 Jefferson St',
#                                'address2': '',
#                                'address3': '',
#                                'city': 'San Francisco',
#                                'country': 'US',
#                                'display_address': ['340 Jefferson St',
#                                                    'San Francisco, CA 94133'],
#                                'state': 'CA',
#                                'zip_code': '94133'},
#                   'name': "Pompei's Grotto",
#                   'phone': '+14157769265',
#                   'price': '$$',
#                   'rating': 3.0,
#                   'review_count': 599,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/pompeis-grotto-san-francisco?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'},
#                  {'alias': 'krispy-kreme-san-francisco',
#                   'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#                                  {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#                   'coordinates': {'latitude': 37.807733,
#                                   'longitude': -122.418347},
#                   'display_phone': '(415) 775-1123',
#                   'distance': 145.6649819002592,
#                   'id': 'FohKH2jvDGLo8DOLdiiDog',
#                   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NrJ5NKru0CvOy0_kX0iJYQ/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '353 Jefferson St',
#                                'address2': '',
#                                'address3': None,
#                                'city': 'San Francisco',
#                                'country': 'US',
#                                'display_address': ['353 Jefferson St',
#                                                    'San Francisco, CA 94133'],
#                                'state': 'CA',
#                                'zip_code': '94133'},
#                   'name': 'Krispy Kreme',
#                   'phone': '+14157751123',
#                   'price': '$',
#                   'rating': 3.5,
#                   'review_count': 68,
#                   'transactions': ['delivery', 'pickup'],
#                   'url': 'https://www.yelp.com/biz/krispy-kreme-san-francisco?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'},
#                  {'alias': 'waterfront-bakery-san-francisco',
#                   'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#                   'coordinates': {'latitude': 37.807182,
#                                   'longitude': -122.419129},
#                   'display_phone': '(415) 775-2300',
#                   'distance': 157.80970345539313,
#                   'id': 'T1BuzZTXl9fjT31wbG1GuA',
#                   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/tJcOJQ4xu4zB0rfLR1tL2g/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '2801 Leavenworth St',
#                                'address2': 'Ste 1',
#                                'address3': '',
#                                'city': 'San Francisco',
#                                'country': 'US',
#                                'display_address': ['2801 Leavenworth St',
#                                                    'Ste 1',
#                                                    'San Francisco, CA 94133'],
#                                'state': 'CA',
#                                'zip_code': '94133'},
#                   'name': 'Waterfront Bakery',
#                   'phone': '+14157752300',
#                   'price': '$',
#                   'rating': 3.5,
#                   'review_count': 76,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/waterfront-bakery-san-francisco?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'},
#                  {'alias': 'subway-san-francisco-24',
#                   'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#                                  {'alias': 'sandwiches',
#                                   'title': 'Sandwiches'}],
#                   'coordinates': {'latitude': 37.807698,
#                                   'longitude': -122.418162},
#                   'display_phone': '(415) 346-9100',
#                   'distance': 161.01911574266288,
#                   'id': 'vvLjKk0pU_a3u-Es59I2JA',
#                   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MAyvwgXoo6J67sPA-TsLDA/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '333 Jefferson St',
#                                'address2': 'Ste125',
#                                'address3': '',
#                                'city': 'San Francisco',
#                                'country': 'US',
#                                'display_address': ['333 Jefferson St',
#                                                    'Ste125',
#                                                    'San Francisco, CA 94133'],
#                                'state': 'CA',
#                                'zip_code': '94133'},
#                   'name': 'Subway',
#                   'phone': '+14153469100',
#                   'price': '$',
#                   'rating': 2.0,
#                   'review_count': 29,
#                   'transactions': ['delivery', 'pickup'],
#                   'url': 'https://www.yelp.com/biz/subway-san-francisco-24?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'},
#                  {'alias': 'quickly-san-francisco-28',
#                   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#                                  {'alias': 'bubbletea', 'title': 'Bubble Tea'},
#                                  {'alias': 'asianfusion',
#                                   'title': 'Asian Fusion'}],
#                   'coordinates': {'latitude': 37.807388,
#                                   'longitude': -122.418541},
#                   'display_phone': '(415) 988-1660',
#                   'distance': 161.07772250814236,
#                   'id': '_wZlW8K6aBKfyBPVzyBRMg',
#                   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Az21SVYM5qtkbH1oZWVhgw/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '2800 Leavenworth St',
#                                'address2': 'Ste A11',
#                                'address3': 'Fisherman Wharf',
#                                'city': 'San Francisco',
#                                'country': 'US',
#                                'display_address': ['2800 Leavenworth St',
#                                                    'Ste A11',
#                                                    'Fisherman Wharf',
#                                                    'San Francisco, CA 94133'],
#                                'state': 'CA',
#                                'zip_code': '94133'},
#                   'name': 'Quickly',
#                   'phone': '+14159881660',
#                   'price': '$',
#                   'rating': 3.0,
#                   'review_count': 54,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/quickly-san-francisco-28?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'},
#                  {'alias': 'lous-fish-shack-san-francisco',
#                   'categories': [{'alias': 'jazzandblues',
#                                   'title': 'Jazz & Blues'},
#                                  {'alias': 'seafood', 'title': 'Seafood'},
#                                  {'alias': 'salad', 'title': 'Salad'}],
#                   'coordinates': {'latitude': 37.8080851609142,
#                                   'longitude': -122.417820553872},
#                   'display_phone': '(415) 771-5687',
#                   'distance': 168.7841568998967,
#                   'id': 'djqM0f9jSqWx_xOnIIu19A',
#                   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rAtlhOzpCXU80HdEI-fXYA/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '300 Jefferson St',
#                                'address2': '',
#                                'address3': '',
#                                'city': 'San Francisco',
#                                'country': 'US',
#                                'display_address': ['300 Jefferson St',
#                                                    'San Francisco, CA 94133'],
#                                'state': 'CA',
#                                'zip_code': '94133'},
#                   'name': "Lou's Fish Shack",
#                   'phone': '+14157715687',
#                   'price': '$$',
#                   'rating': 3.0,
#                   'review_count': 688,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/lous-fish-shack-san-francisco?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'},
#                  {'alias': 'the-roc-sf-bar-and-nightclub-san-francisco-2',
#                   'categories': [{'alias': 'danceclubs',
#                                   'title': 'Dance Clubs'},
#                                  {'alias': 'sportsbars',
#                                   'title': 'Sports Bars'},
#                                  {'alias': 'venues',
#                                   'title': 'Venues & Event Spaces'}],
#                   'coordinates': {'latitude': 37.80727,
#                                   'longitude': -122.41947},
#                   'display_phone': '(415) 650-6038',
#                   'distance': 170.49259011186754,
#                   'id': 'TAKf2m58vmL_SpQ-fWnP1A',
#                   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Pbdm2b0B-oX-sCrTqLfP7w/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '2801 Leavenworth St',
#                                'address2': None,
#                                'address3': '',
#                                'city': 'San Francisco',
#                                'country': 'US',
#                                'display_address': ['2801 Leavenworth St',
#                                                    'San Francisco, CA 94133'],
#                                'state': 'CA',
#                                'zip_code': '94133'},
#                   'name': 'THE ROC SF: Bar & Nightclub',
#                   'phone': '+14156506038',
#                   'price': '$$',
#                   'rating': 2.5,
#                   'review_count': 117,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/the-roc-sf-bar-and-nightclub-san-francisco-2?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'},
#                  {'alias': 'normans-ice-cream-and-freezes-san-francisco',
#                   'categories': [{'alias': 'icecream',
#                                   'title': 'Ice Cream & Frozen Yogurt'},
#                                  {'alias': 'coffee', 'title': 'Coffee & Tea'},
#                                  {'alias': 'juicebars',
#                                   'title': 'Juice Bars & Smoothies'}],
#                   'coordinates': {'latitude': 37.80727,
#                                   'longitude': -122.41947},
#                   'display_phone': '(415) 346-3046',
#                   'distance': 170.49259011186754,
#                   'id': 'sfAIpzEC8ywpy36YhzikmQ',
#                   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pgWMRXGnPXVzR-rabJ2DGw/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '2801 Leavenworth St',
#                                'address2': '',
#                                'address3': '',
#                                'city': 'San Francisco',
#                                'country': 'US',
#                                'display_address': ['2801 Leavenworth St',
#                                                    'San Francisco, CA 94133'],
#                                'state': 'CA',
#                                'zip_code': '94133'},
#                   'name': "Norman's Ice Cream & Freezes",
#                   'phone': '+14153463046',
#                   'price': '$',
#                   'rating': 4.5,
#                   'review_count': 289,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/normans-ice-cream-and-freezes-san-francisco?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'},
#                  {'alias': 'fishermans-pizzeria-san-francisco',
#                   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#                   'coordinates': {'latitude': 37.806981,
#                                   'longitude': -122.418778},
#                   'display_phone': '(415) 928-2998',
#                   'distance': 189.58915628542263,
#                   'id': '8ev-d1sPjE3mSMHUAtJS6A',
#                   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/n2pUGIpN3gVtBysBIkTZQg/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '2800 Leavenworth St',
#                                'address2': 'Ste 50',
#                                'address3': '',
#                                'city': 'San Francisco',
#                                'country': 'US',
#                                'display_address': ['2800 Leavenworth St',
#                                                    'Ste 50',
#                                                    'San Francisco, CA 94133'],
#                                'state': 'CA',
#                                'zip_code': '94133'},
#                   'name': "Fisherman's Pizzeria",
#                   'phone': '+14159282998',
#                   'price': '$$',
#                   'rating': 2.0,
#                   'review_count': 190,
#                   'transactions': ['delivery', 'pickup'],
#                   'url': 'https://www.yelp.com/biz/fishermans-pizzeria-san-francisco?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'},
#                  {'alias': 'castagnolas-san-francisco',
#                   'categories': [{'alias': 'jazzandblues',
#                                   'title': 'Jazz & Blues'},
#                                  {'alias': 'steak', 'title': 'Steakhouses'},
#                                  {'alias': 'seafood', 'title': 'Seafood'}],
#                   'coordinates': {'latitude': 37.8081022,
#                                   'longitude': -122.4175276},
#                   'display_phone': '(415) 776-5015',
#                   'distance': 193.00910640840817,
#                   'id': '5tmp6OoIzM6af3717J3tFQ',
#                   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Vmc3KNyxfBpKxFIS6_OKog/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '286 Jefferson St',
#                                'address2': '',
#                                'address3': '',
#                                'city': 'San Francisco',
#                                'country': 'US',
#                                'display_address': ['286 Jefferson St',
#                                                    'San Francisco, CA 94133'],
#                                'state': 'CA',
#                                'zip_code': '94133'},
#                   'name': "Castagnola's",
#                   'phone': '+14157765015',
#                   'price': '$$',
#                   'rating': 2.5,
#                   'review_count': 612,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/castagnolas-san-francisco?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'},
#                  {'alias': 'chipotle-mexican-grill-san-francisco-6',
#                   'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#                                  {'alias': 'hotdogs', 'title': 'Fast Food'}],
#                   'coordinates': {'latitude': 37.80747,
#                                   'longitude': -122.41782},
#                   'display_phone': '(415) 500-3533',
#                   'distance': 194.16531238281704,
#                   'id': 'KnXtpQyJrIj6ROHWciP29g',
#                   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/S-5gHH839oqyBR5oe1SC1w/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '333 Jefferson St',
#                                'address2': 'Ste 104',
#                                'address3': '',
#                                'city': 'San Francisco',
#                                'country': 'US',
#                                'display_address': ['333 Jefferson St',
#                                                    'Ste 104',
#                                                    'San Francisco, CA 94133'],
#                                'state': 'CA',
#                                'zip_code': '94133'},
#                   'name': 'Chipotle Mexican Grill',
#                   'phone': '+14155003533',
#                   'price': '$',
#                   'rating': 2.5,
#                   'review_count': 137,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/chipotle-mexican-grill-san-francisco-6?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'},
#                  {'alias': 'fiddlers-green-of-sf-san-francisco',
#                   'categories': [{'alias': 'sportsbars',
#                                   'title': 'Sports Bars'},
#                                  {'alias': 'irish_pubs', 'title': 'Irish Pub'},
#                                  {'alias': 'danceclubs',
#                                   'title': 'Dance Clubs'}],
#                   'coordinates': {'latitude': 37.80646,
#                                   'longitude': -122.41954},
#                   'display_phone': '(415) 655-3220',
#                   'distance': 221.93939175408732,
#                   'id': 'gIGjXJqZaSzAuV_Jy2dCnw',
#                   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BUN2G_PKipRPoHPutFZ68A/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '1333 Columbus Ave',
#                                'address2': '',
#                                'address3': '',
#                                'city': 'San Francisco',
#                                'country': 'US',
#                                'display_address': ['1333 Columbus Ave',
#                                                    'San Francisco, CA 94133'],
#                                'state': 'CA',
#                                'zip_code': '94133'},
#                   'name': "Fiddler's Green of SF",
#                   'phone': '+14156553220',
#                   'price': '$$',
#                   'rating': 3.5,
#                   'review_count': 349,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/fiddlers-green-of-sf-san-francisco?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'},
#                  {'alias': 'carmel-pizza-company-san-francisco',
#                   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#                   'coordinates': {'latitude': 37.8075970299193,
#                                   'longitude': -122.417328357697},
#                   'display_phone': '(415) 676-1185',
#                   'distance': 229.59489867323455,
#                   'id': 'IhVsaINdU_Syqp23JuKzrA',
#                   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8LLtWgfeR68B42vLAu55AA/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '2826 Jones St',
#                                'address2': '',
#                                'address3': '',
#                                'city': 'San Francisco',
#                                'country': 'US',
#                                'display_address': ['2826 Jones St',
#                                                    'San Francisco, CA 94133'],
#                                'state': 'CA',
#                                'zip_code': '94133'},
#                   'name': 'Carmel Pizza Company',
#                   'phone': '+14156761185',
#                   'price': '$$',
#                   'rating': 4.5,
#                   'review_count': 748,
#                   'transactions': ['delivery', 'pickup'],
#                   'url': 'https://www.yelp.com/biz/carmel-pizza-company-san-francisco?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'},
#                  {'alias': 'starbucks-san-francisco-220',
#                   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#                   'coordinates': {'latitude': 37.806565,
#                                   'longitude': -122.420423837937},
#                   'display_phone': '(415) 409-0840',
#                   'distance': 229.718758906538,
#                   'id': '78pw8GJBTUWgvG5JckJYSg',
#                   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oLoVHj4iBsAfelD511GV9Q/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '685 Beach Street',
#                                'address2': '',
#                                'address3': '',
#                                'city': 'San Francisco',
#                                'country': 'US',
#                                'display_address': ['685 Beach Street',
#                                                    'San Francisco, CA 94109'],
#                                'state': 'CA',
#                                'zip_code': '94109'},
#                   'name': 'Starbucks',
#                   'phone': '+14154090840',
#                   'price': '$',
#                   'rating': 2.5,
#                   'review_count': 94,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/starbucks-san-francisco-220?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'},
#                  {'alias': 'joanies-happy-days-diner-san-francisco',
#                   'categories': [{'alias': 'diners', 'title': 'Diners'}],
#                   'coordinates': {'latitude': 37.80639, 'longitude': -122.4194},
#                   'display_phone': '(415) 928-4343',
#                   'distance': 231.44500395599036,
#                   'id': 'ssGyoOJwpxswEd8m3GAmsw',
#                   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cVC2bltu4NR72hW437NGbw/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '1329 Columbus Ave',
#                                'address2': '',
#                                'address3': '',
#                                'city': 'San Francisco',
#                                'country': 'US',
#                                'display_address': ['1329 Columbus Ave',
#                                                    'San Francisco, CA 94133'],
#                                'state': 'CA',
#                                'zip_code': '94133'},
#                   'name': "Joanie's Happy Days Diner",
#                   'phone': '+14159284343',
#                   'price': '$$',
#                   'rating': 4.0,
#                   'review_count': 396,
#                   'transactions': ['pickup'],
#                   'url': 'https://www.yelp.com/biz/joanies-happy-days-diner-san-francisco?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'},
#                  {'alias': 'pizza-zone-san-francisco',
#                   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#                   'coordinates': {'latitude': 37.80681,
#                                   'longitude': -122.41801},
#                   'display_phone': '(415) 567-3244',
#                   'distance': 231.4762379542414,
#                   'id': 'wtP5sfAxmBfWypUhNbdAww',
#                   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jYl1LJyWcqJdtk4WZ8yQ9A/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '555 Beach St',
#                                'address2': '',
#                                'address3': '',
#                                'city': 'San Francisco',
#                                'country': 'US',
#                                'display_address': ['555 Beach St',
#                                                    'San Francisco, CA 94133'],
#                                'state': 'CA',
#                                'zip_code': '94133'},
#                   'name': 'Pizza Zone',
#                   'phone': '+14155673244',
#                   'price': '$',
#                   'rating': 3.5,
#                   'review_count': 147,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/pizza-zone-san-francisco?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'},
#                  {'alias': 'tanguito-san-francisco',
#                   'categories': [{'alias': 'argentine', 'title': 'Argentine'},
#                                  {'alias': 'burgers', 'title': 'Burgers'},
#                                  {'alias': 'empanadas', 'title': 'Empanadas'}],
#                   'coordinates': {'latitude': 37.807614,
#                                   'longitude': -122.417203},
#                   'display_phone': '(415) 577-4223',
#                   'distance': 238.62721705360966,
#                   'id': 'AdupguljIIejtEOnExddkQ',
#                   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/21lsWAl9dwUT6TM9Mwq-fw/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '2850 Jones St',
#                                'address2': '',
#                                'address3': '',
#                                'city': 'San Francisco',
#                                'country': 'US',
#                                'display_address': ['2850 Jones St',
#                                                    'San Francisco, CA 94133'],
#                                'state': 'CA',
#                                'zip_code': '94133'},
#                   'name': 'Tanguito',
#                   'phone': '+14155774223',
#                   'price': '$',
#                   'rating': 4.5,
#                   'review_count': 570,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/tanguito-san-francisco?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'},
#                  {'alias': 'getfresh-sf-san-francisco',
#                   'categories': [{'alias': 'juicebars',
#                                   'title': 'Juice Bars & Smoothies'},
#                                  {'alias': 'sandwiches', 'title': 'Sandwiches'},
#                                  {'alias': 'foodstands',
#                                   'title': 'Food Stands'}],
#                   'coordinates': {'latitude': 37.8073988897921,
#                                   'longitude': -122.417304217815},
#                   'display_phone': '(415) 407-1377',
#                   'distance': 242.25442799441544,
#                   'id': 'd8RqHoarFt_uTIkASZOOxA',
#                   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5jK2yIHcjgdbvpt2gf-gBQ/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '2828 Jones St',
#                                'address2': '',
#                                'address3': None,
#                                'city': 'San Francisco',
#                                'country': 'US',
#                                'display_address': ['2828 Jones St',
#                                                    'San Francisco, CA 94133'],
#                                'state': 'CA',
#                                'zip_code': '94133'},
#                   'name': 'GetFresh SF',
#                   'phone': '+14154071377',
#                   'price': '$',
#                   'rating': 4.5,
#                   'review_count': 85,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/getfresh-sf-san-francisco?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'},
#                  {'alias': 'the-buena-vista-san-francisco',
#                   'categories': [{'alias': 'bars', 'title': 'Bars'},
#                                  {'alias': 'cafes', 'title': 'Cafes'},
#                                  {'alias': 'breakfast_brunch',
#                                   'title': 'Breakfast & Brunch'}],
#                   'coordinates': {'latitude': 37.806509097529,
#                                   'longitude': -122.42072219051},
#                   'display_phone': '(415) 474-5044',
#                   'distance': 244.48297466368325,
#                   'id': 'wdlyeH5ug7uZpvtb-N97fQ',
#                   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eftZbD2bBRhLX52OACg5Qg/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '2765 Hyde St',
#                                'address2': '',
#                                'address3': '',
#                                'city': 'San Francisco',
#                                'country': 'US',
#                                'display_address': ['2765 Hyde St',
#                                                    'San Francisco, CA 94109'],
#                                'state': 'CA',
#                                'zip_code': '94109'},
#                   'name': 'The Buena Vista',
#                   'phone': '+14154745044',
#                   'price': '$$',
#                   'rating': 4.0,
#                   'review_count': 2416,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/the-buena-vista-san-francisco?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'},
#                  {'alias': 'bay-city-bike-rentals-and-tours-san-francisco-2',
#                   'categories': [{'alias': 'bikerentals',
#                                   'title': 'Bike Rentals'},
#                                  {'alias': 'bustours', 'title': 'Bus Tours'},
#                                  {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#                   'coordinates': {'latitude': 37.807282,
#                                   'longitude': -122.4173033},
#                   'display_phone': '(415) 346-2453',
#                   'distance': 249.37096924285862,
#                   'id': 'L_FIjNV7QLW3HATEIXHrnw',
#                   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SISvQwCBz10otE9I1yz_ig/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '2828 Jones St',
#                                'address2': '',
#                                'address3': '',
#                                'city': 'San Francisco',
#                                'country': 'US',
#                                'display_address': ['2828 Jones St',
#                                                    'San Francisco, CA 94133'],
#                                'state': 'CA',
#                                'zip_code': '94133'},
#                   'name': 'Bay City Bike Rentals & Tours',
#                   'phone': '+14153462453',
#                   'price': '$$',
#                   'rating': 3.5,
#                   'review_count': 9,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/bay-city-bike-rentals-and-tours-san-francisco-2?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'},
#                  {'alias': 'eight-am-san-francisco',
#                   'categories': [{'alias': 'newamerican',
#                                   'title': 'American (New)'},
#                                  {'alias': 'breakfast_brunch',
#                                   'title': 'Breakfast & Brunch'}],
#                   'coordinates': {'latitude': 37.806251,
#                                   'longitude': -122.419204},
#                   'display_phone': '(415) 292-4888',
#                   'distance': 252.23194962856763,
#                   'id': '4-ra3RxOy1PpvnaK49dy8w',
#                   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MER73gsf0I4b4FcCzg7udw/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '1323 Columbus Ave',
#                                'address2': '',
#                                'address3': '',
#                                'city': 'San Francisco',
#                                'country': 'US',
#                                'display_address': ['1323 Columbus Ave',
#                                                    'San Francisco, CA 94133'],
#                                'state': 'CA',
#                                'zip_code': '94133'},
#                   'name': 'Eight AM',
#                   'phone': '+14152924888',
#                   'price': '$$',
#                   'rating': 4.5,
#                   'review_count': 1106,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/eight-am-san-francisco?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'},
#                  {'alias': 'the-baked-bear-custom-ice-cream-sandwiches-san-francisco-5',
#                   'categories': [{'alias': 'icecream',
#                                   'title': 'Ice Cream & Frozen Yogurt'},
#                                  {'alias': 'bakeries', 'title': 'Bakeries'}],
#                   'coordinates': {'latitude': 37.8072919,
#                                   'longitude': -122.417122},
#                   'display_phone': '(415) 757-0052',
#                   'distance': 253.44865944300847,
#                   'id': 'W01ZzmeWz0vJip3TVDmdyA',
#                   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/aRJrNs8ur5CHLWL76UKeJg/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '2824 Jones St',
#                                'address2': '',
#                                'address3': '',
#                                'city': 'San Francisco',
#                                'country': 'US',
#                                'display_address': ['2824 Jones St',
#                                                    'San Francisco, CA 94133'],
#                                'state': 'CA',
#                                'zip_code': '94133'},
#                   'name': 'The Baked Bear - Custom Ice Cream Sandwiches',
#                   'phone': '+14157570052',
#                   'price': '$',
#                   'rating': 4.5,
#                   'review_count': 372,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/the-baked-bear-custom-ice-cream-sandwiches-san-francisco-5?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'},
# ...
#                                   'longitude': -122.416155},
#                   'display_phone': '(415) 674-4129',
#                   'distance': 315.1157500038756,
#                   'id': 'O4PouD2wvkoZ6yYddQ53EQ',
#                   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mItcNRIQIZIi8J0E8pYs4g/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '2739 Taylor Street',
#                                'address2': '',
#                                'address3': '',
#                                'city': 'San Francisco',
#                                'country': 'US',
#                                'display_address': ['2739 Taylor Street',
#                                                    'San Francisco, CA 94133'],
#                                'state': 'CA',
#                                'zip_code': '94133'},
#                   'name': 'Jack In The Box',
#                   'phone': '+14156744129',
#                   'price': '$',
#                   'rating': 3.0,
#                   'review_count': 25,
#                   'transactions': ['delivery'],
#                   'url': 'https://www.yelp.com/biz/jack-in-the-box-san-francisco-10?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'},
#                  {'alias': 'latte-express-san-francisco-3',
#                   'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#                                  {'alias': 'coffee', 'title': 'Coffee & Tea'},
#                                  {'alias': 'vietnamese',
#                                   'title': 'Vietnamese'}],
#                   'coordinates': {'latitude': 37.8073319,
#                                   'longitude': -122.4163074},
#                   'display_phone': '(415) 775-4293',
#                   'distance': 317.48108135300885,
#                   'id': 'epVk9nlZILCavOh5zLwPaA',
#                   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/owzG4cKMF5PwduiFH81mxQ/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '448 Beach St',
#                                'address2': '',
#                                'address3': '',
#                                'city': 'San Francisco',
#                                'country': 'US',
#                                'display_address': ['448 Beach St',
#                                                    'San Francisco, CA 94133'],
#                                'state': 'CA',
#                                'zip_code': '94133'},
#                   'name': 'Latte Express',
#                   'phone': '+14157754293',
#                   'price': '$',
#                   'rating': 3.5,
#                   'review_count': 19,
#                   'transactions': ['pickup'],
#                   'url': 'https://www.yelp.com/biz/latte-express-san-francisco-3?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'},
#                  {'alias': 'nicks-lighthouse-san-francisco',
#                   'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#                   'coordinates': {'latitude': 37.8083438426256,
#                                   'longitude': -122.415866553783},
#                   'display_phone': '(415) 929-1300',
#                   'distance': 323.364026472717,
#                   'id': '-zbfFXqxIU2tgRju6n9ziw',
#                   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/0WWbX6T0w0MRL-B1Khv8fw/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '2815 Taylor St',
#                                'address2': '',
#                                'address3': 'Fishermans Wharf',
#                                'city': 'San Francisco',
#                                'country': 'US',
#                                'display_address': ['2815 Taylor St',
#                                                    'Fishermans Wharf',
#                                                    'San Francisco, CA 94102'],
#                                'state': 'CA',
#                                'zip_code': '94102'},
#                   'name': "Nick's Lighthouse",
#                   'phone': '+14159291300',
#                   'price': '$$',
#                   'rating': 3.0,
#                   'review_count': 918,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/nicks-lighthouse-san-francisco?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'},
#                  {'alias': 'guardinos-san-francisco',
#                   'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#                   'coordinates': {'latitude': 37.8083438426256,
#                                   'longitude': -122.415866553783},
#                   'display_phone': '(415) 775-3669',
#                   'distance': 324.2130780659675,
#                   'id': '90KBIQKFFZTGM_vXeF2vwg',
#                   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tD0lza6Ldr3S6X1UkG6afw/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '2801 Taylor St',
#                                'address2': '',
#                                'address3': '',
#                                'city': 'San Francisco',
#                                'country': 'US',
#                                'display_address': ['2801 Taylor St',
#                                                    'San Francisco, CA 94133'],
#                                'state': 'CA',
#                                'zip_code': '94133'},
#                   'name': "Guardino's",
#                   'phone': '+14157753669',
#                   'price': '$',
#                   'rating': 3.5,
#                   'review_count': 128,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/guardinos-san-francisco?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'},
#                  {'alias': 'sabella-and-la-torre-san-francisco',
#                   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#                                  {'alias': 'italian', 'title': 'Italian'},
#                                  {'alias': 'bars', 'title': 'Bars'}],
#                   'coordinates': {'latitude': 37.8083438426256,
#                                   'longitude': -122.415866553783},
#                   'display_phone': '(415) 673-2824',
#                   'distance': 326.84810815684415,
#                   'id': 'xJOqHjh0EpCww-rNla6iPA',
#                   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PzMs5Xl5RrhPU3lxmnTOCw/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '2809 Taylor St',
#                                'address2': '',
#                                'address3': '',
#                                'city': 'San Francisco',
#                                'country': 'US',
#                                'display_address': ['2809 Taylor St',
#                                                    'San Francisco, CA 94133'],
#                                'state': 'CA',
#                                'zip_code': '94133'},
#                   'name': 'Sabella & La Torre',
#                   'phone': '+14156732824',
#                   'price': '$$',
#                   'rating': 3.5,
#                   'review_count': 781,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/sabella-and-la-torre-san-francisco?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'},
#                  {'alias': 'aroma-tea-shop-san-francisco-6',
#                   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#                                  {'alias': 'tea', 'title': 'Tea Rooms'}],
#                   'coordinates': {'latitude': 37.8074299,
#                                   'longitude': -122.41665},
#                   'display_phone': '(415) 308-9594',
#                   'distance': 327.34701777655073,
#                   'id': '4xCg6hKEjbJW3DAeivAGBg',
#                   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9rSVwJzszcocKY1CPJinBA/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '430 Beach St',
#                                'address2': '',
#                                'address3': None,
#                                'city': 'San Francisco',
#                                'country': 'US',
#                                'display_address': ['430 Beach St',
#                                                    'San Francisco, CA 94133'],
#                                'state': 'CA',
#                                'zip_code': '94133'},
#                   'name': 'Aroma Tea Shop',
#                   'phone': '+14153089594',
#                   'price': '$$',
#                   'rating': 5.0,
#                   'review_count': 13,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/aroma-tea-shop-san-francisco-6?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'},
#                  {'alias': 'the-crab-station-san-francisco',
#                   'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#                   'coordinates': {'latitude': 37.8083438426256,
#                                   'longitude': -122.415866553783},
#                   'display_phone': '(415) 474-8796',
#                   'distance': 329.2983485492449,
#                   'id': 'Q19bgCMzGsG4Ao06F0hpjg',
#                   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/T8_M3fW0FAbxjwFKmmk7QA/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '2803 Taylor St',
#                                'address2': '',
#                                'address3': '',
#                                'city': 'San Francisco',
#                                'country': 'US',
#                                'display_address': ['2803 Taylor St',
#                                                    'San Francisco, CA 94133'],
#                                'state': 'CA',
#                                'zip_code': '94133'},
#                   'name': 'The Crab Station',
#                   'phone': '+14154748796',
#                   'price': '$$',
#                   'rating': 3.5,
#                   'review_count': 298,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/the-crab-station-san-francisco?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'},
#                  {'alias': 'darrens-cafe-san-francisco',
#                   'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#                                  {'alias': 'breakfast_brunch',
#                                   'title': 'Breakfast & Brunch'},
#                                  {'alias': 'cafes', 'title': 'Cafes'}],
#                   'coordinates': {'latitude': 37.80753,
#                                   'longitude': -122.41587},
#                   'display_phone': '(415) 673-3345',
#                   'distance': 349.0012473257965,
#                   'id': '0a22L8UI1KEy8-VxMnfqaQ',
#                   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LCnR64tZx0Qr6cDIeS-xKQ/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '2731 Taylor St',
#                                'address2': '',
#                                'address3': '',
#                                'city': 'San Francisco',
#                                'country': 'US',
#                                'display_address': ['2731 Taylor St',
#                                                    'San Francisco, CA 94133'],
#                                'state': 'CA',
#                                'zip_code': '94133'},
#                   'name': "Darren's Cafe",
#                   'phone': '+14156733345',
#                   'price': '$$',
#                   'rating': 4.0,
#                   'review_count': 522,
#                   'transactions': ['pickup'],
#                   'url': 'https://www.yelp.com/biz/darrens-cafe-san-francisco?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'},
#                  {'alias': 'chennai-kings-san-francisco',
#                   'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#                   'coordinates': {'latitude': 37.8073464408458,
#                                   'longitude': -122.415976524353},
#                   'display_phone': '(415) 929-6983',
#                   'distance': 349.2244809358424,
#                   'id': 'T3BT4zP92QDAIUZHw7_vdg',
#                   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/jWzsU_UKm9p17jC9f-oUoQ/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '418 Beach St',
#                                'address2': '',
#                                'address3': '',
#                                'city': 'San Francisco',
#                                'country': 'US',
#                                'display_address': ['418 Beach St',
#                                                    'San Francisco, CA 94133'],
#                                'state': 'CA',
#                                'zip_code': '94133'},
#                   'name': 'Chennai Kings',
#                   'phone': '+14159296983',
#                   'price': '$$',
#                   'rating': 3.5,
#                   'review_count': 146,
#                   'transactions': ['delivery', 'pickup'],
#                   'url': 'https://www.yelp.com/biz/chennai-kings-san-francisco?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'},
#                  {'alias': 'fishermans-wharf-chowder-and-crab-sidewalk-stands-san-francisco',
#                   'categories': [{'alias': 'foodstands',
#                                   'title': 'Food Stands'},
#                                  {'alias': 'seafood', 'title': 'Seafood'},
#                                  {'alias': 'soup', 'title': 'Soup'}],
#                   'coordinates': {'latitude': 37.8082513064146,
#                                   'longitude': -122.415970489383},
#                   'display_phone': '',
#                   'distance': 352.20539739038435,
#                   'id': 'q21-izqsFPYZnL83X660Tg',
#                   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MkZQKcfWiQKP7WyeUA7CTQ/o.jpg',
#                   'is_closed': False,
#                   'location': {'address1': '200 Jefferson St',
#                                'address2': None,
#                                'address3': '',
#                                'city': 'San Francisco',
#                                'country': 'US',
#                                'display_address': ['200 Jefferson St',
#                                                    'San Francisco, CA 94133'],
#                                'state': 'CA',
#                                'zip_code': '94133'},
#                   'name': "Fisherman's Wharf  Chowder and Crab Sidewalk Stands",
#                   'phone': '',
#                   'price': '$$',
#                   'rating': 3.5,
#                   'review_count': 394,
#                   'transactions': [],
#                   'url': 'https://www.yelp.com/biz/fishermans-wharf-chowder-and-crab-sidewalk-stands-san-francisco?adjust_creative=8gRFUWzzMWsEwxwVVGNHpA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8gRFUWzzMWsEwxwVVGNHpA'}],
#   'region': {'center': {'latitude': 37.8085393, 'longitude': -122.4196538}},
#   'total': 8500}]

# %%
name = []
latitude = []
longitude = []
price = []
reviewcount = []
citynames = []

for i in range(0, len(responses)):
    for x in range(0,len(responses[i]['businesses'])):
        name.append(responses[i]['businesses'][x]['alias'])
        latitude.append(responses[i]['businesses'][x]['coordinates']['latitude'])
        longitude.append(responses[i]['businesses'][x]['coordinates']['longitude'])
        price.append(responses[i]['businesses'][x]['price'])
        reviewcount.append(responses[i]['businesses'][x]['review_count'])
        citynames.append(cities[i].city_name)

# %%
df_restaurants = pd.DataFrame(
    {'Region': citynames,
     'Name': name,
     'Price': price,
     'Review Count': reviewcount,
     'latitude': latitude,
     'longitude': longitude
    }

)

# %%
df_restaurants
# Out:
#           Region                        Name Price  Review Count   latitude  \
# 0         somers         mcdonalds-kenosha-4     $             4  42.603979
# 1         somers        mcdonalds-kenosha-11     $            11  42.570651
# 2         somers        mcdonalds-kenosha-10     $            15  42.588772
# 3         somers         mcdonalds-kenosha-9     $             6  42.565345
# 4         somers         mcdonalds-kenosha-2     $             3  42.623509
# 5         somers         mcdonalds-kenosha-7     $            19  42.568067
# 6         somers        mcdonalds-kenosha-12     $             8  42.556901
# 7         somers  mcdonalds-pleasant-prairie     $            18  42.522390
# 8         somers         mcdonalds-racine-13     $             6  42.687820
# 9         somers            mcdonalds-racine     $            11  42.702006
# 10        somers          mcdonalds-racine-7     $             9  42.703745
# 11        somers          mcdonalds-racine-2     $             8  42.720402
# 12        somers     mcdonalds-mt-pleasant-6     $             9  42.723927
# 13        somers       mcdonalds-union-grove     $             7  42.680528
# 14        somers              mcdonalds-zion     $            10  42.458296
# 15        somers         mcdonalds-racine-11     $             4  42.732152
# 16        somers             mcdonalds-salem     $            11  42.567749
# 17        somers       mcdonalds-wadsworth-4     $             4  42.429741
# 18        somers        mcdonalds-beach-park     $             5  42.429334
# 19        somers         mcdonalds-racine-10     $            10  42.756598
# 20        somers         mcdonalds-antioch-7     $            35  42.471242
# 21        somers       mcdonalds-caledonia-2     $            17  42.787036
# 22        somers        mcdonalds-waukegan-3     $             9  42.388087
# 23        somers     mcdonalds-lindenhurst-4     $             7  42.407071
# 24        somers          mcdonalds-gurnee-4     $            12  42.385984
# 25        somers          mcdonalds-gurnee-3     $            11  42.377874
# 26        somers            mcdonalds-gurnee     $            19  42.377818
# 27        somers      mcdonalds-lake-villa-2     $            11  42.415157
# 28        somers        mcdonalds-waukegan-4     $             5  42.369971
# 29        somers        mcdonalds-waukegan-5     $             8  42.364068
# ..           ...                         ...   ...           ...        ...
# 74   leon valley    mcdonalds-san-antonio-98     $             6  29.564240
# 75   leon valley    mcdonalds-san-antonio-28     $            13  29.507080
# 76   leon valley   mcdonalds-san-antonio-112     $            14  29.444314
# 77   leon valley    mcdonalds-san-antonio-67     $             9  29.405641
# 78   leon valley    mcdonalds-san-antonio-22     $            32  29.547060
# 79   leon valley    mcdonalds-san-antonio-19     $             8  29.419917
# 80   leon valley    mcdonalds-san-antonio-41     $            19  29.574184
# 81   leon valley    mcdonalds-san-antonio-57     $            21  29.440002
# 82   leon valley    mcdonalds-san-antonio-93     $            25  29.550325
# 83   leon valley    mcdonalds-san-antonio-85     $             7  29.515400
# 84   leon valley    mcdonalds-san-antonio-25     $             7  29.406636
# 85   leon valley    mcdonalds-san-antonio-24     $             2  29.416470
# 86   leon valley    mcdonalds-san-antonio-94     $             8  29.397550
# 87   leon valley    mcdonalds-san-antonio-14     $            14  29.426997
# 88   leon valley    mcdonalds-san-antonio-21     $            22  29.461415
# 89   leon valley    mcdonalds-san-antonio-17     $            30  29.515961
# 90   leon valley    mcdonalds-san-antonio-23     $            27  29.588331
# 91   leon valley     mcdonalds-san-antonio-5     $             5  29.500340
# 92   leon valley    mcdonalds-san-antonio-87     $            18  29.411789
# 93   leon valley    mcdonalds-san-antonio-42     $            21  29.469975
# 94   leon valley    mcdonalds-san-antonio-11     $            56  29.423837
# 95   leon valley    mcdonalds-san-antonio-31     $            35  29.496900
# 96   leon valley    mcdonalds-san-antonio-26     $            30  29.519788
# 97   leon valley    mcdonalds-san-antonio-52     $             4  29.386090
# 98   leon valley    mcdonalds-san-antonio-62     $            19  29.553379
# 99   leon valley   mcdonalds-san-antonio-124     $             9  29.381254
# 100  leon valley    mcdonalds-san-antonio-18     $            30  29.435120
# 101  leon valley    mcdonalds-san-antonio-56     $            28  29.615570
# 102  leon valley    mcdonalds-san-antonio-34     $             4  29.433333
# 103  leon valley       mcdonalds-san-antonio     $            21  29.438399
#
#      longitude
# 0   -87.876337
# 1   -87.887291
# 2   -87.856847
# 3   -87.858329
# 4   -87.846629
# 5   -87.955448
# 6   -87.825823
# 7   -87.946842
# 8   -87.836232
# 9   -87.853464
# 10  -87.826341
# 11  -87.862451
# 12  -87.950644
# 13  -88.050549
# 14  -87.825636
# 15  -87.799489
# 16  -88.117990
# 17  -87.937314
# 18  -87.826352
# 19  -87.799400
# 20  -88.094090
# 21  -87.809712
# 22  -87.854922
# 23  -88.027782
# 24  -87.959542
# 25  -87.904091
# 26  -87.939616
# 27  -88.071516
# 28  -87.881841
# 29  -87.830377
# ..         ...
# 74  -98.595890
# 75  -98.499760
# 76  -98.663429
# 77  -98.575880
# 78  -98.508680
# 79  -98.527578
# 80  -98.545302
# 81  -98.499162
# 82  -98.664460
# 83  -98.482050
# 84  -98.629739
# 85  -98.650135
# 86  -98.557592
# 87  -98.501677
# 88  -98.692275
# 89  -98.695620
# 90  -98.629531
# 91  -98.704677
# 92  -98.506469
# 93  -98.463068
# 94  -98.487644
# 95  -98.710727
# 96  -98.462154
# 97  -98.524607
# 98  -98.468032
# 99  -98.638282
# 100 -98.709340
# 101 -98.604703
# 102 -98.714082
# 103 -98.449782
#
# [104 rows x 6 columns]

# %%
groupedbyregion = df_restaurants.groupby('Region')
groupedbyregion.count()
# Out:
#              Name  Price  Review Count  latitude  longitude
# Region
# douglas         4      4             4         4          4
# leon valley    50     50            50        50         50
# somers         50     50            50        50         50
